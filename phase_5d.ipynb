# %%
# %run phase_space_analysis_5d.py --input data/events_indices.csv
# Out:
# --- Data Loading and Preprocessing ---
# N = 431
# Raw data statistics:
#   Dim 1: mean=8.252900, std=6.332903
#   Dim 2: mean=16.345708, std=8.148547
#   Dim 3: mean=25.044084, std=8.799334
#   Dim 4: mean=33.473318, std=8.517211
#   Dim 5: mean=42.095128, std=6.874134
# Normalized statistics:
#   Dim 1: mean=0.000000, std=1.000000
#   Dim 2: mean=0.000000, std=1.000000
#   Dim 3: mean=0.000000, std=1.000000
#   Dim 4: mean=-0.000000, std=1.000000
#   Dim 5: mean=-0.000000, std=1.000000
#
# --- PCA Explained Variance Ratio ---
#   PC1: 58.0463%
#   PC2: 21.8184%
#   PC3: 9.1212%
#   PC4: 6.6149%
#   PC5: 4.3991%
#
# Poincaré crossings found: 107
#
# Largest Lyapunov Exponent (LLE) = 0.003132
# Interpretation: System is at the edge of chaos (periodic or quasi-periodic)
#
# Recurrence threshold epsilon (10th percentile) = 1.461464
#
# --- Recurrence Quantification Analysis ---
#   RR = 0.100005
#   DET = 0.190029
#   Lmax = 5.000000
#   Lmean = 2.114046
#   ENT = 0.363673
# ...
