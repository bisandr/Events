# %%
# %run predict_5d.py --input data/events_indices.csv --horizon 5
# Out:
# --- Forecast Horizon ---
#   LLE              = 0.003132
#   Initial sep d0   = 0.4977
#   Tolerance        = 1.0000
#   T_max            = 222.8 steps
#   Saved: output\forecast_horizon.png
#
# ...
#   FUTURE FORECAST -- next 5 steps beyond the dataset
# ...
#   (VAR lag order selected: p = 1)
#
# --- Analogues ---
# Step            Dim1          Dim2          Dim3          Dim4          Dim5
# 1             3.0000        9.2000       22.8000       28.6000       42.0000
# 2             7.8000       14.0000       21.2000       31.2000       42.0000
# 3             9.6000       20.2000       28.2000       38.4000       46.8000
# 4             7.6000       15.4000       25.8000       31.4000       43.6000
# 5             5.4000       14.8000       25.0000       34.0000       39.0000
#
# --- LocalLinear ---
# Step            Dim1          Dim2          Dim3          Dim4          Dim5
# 1             6.7578       13.3879       27.4470       34.4828       42.3695
# ...
