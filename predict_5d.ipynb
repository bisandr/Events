# %%
# %run predict_5d.py --input data/events_indices.csv --horizon 5 --test-size 0.2
# Out:
# --- Forecast Horizon ---
#   LLE              = 0.003132
#   Initial sep d0   = 0.4977
#   Tolerance        = 1.0000
#   T_max            = 222.8 steps
#   Saved: output\forecast_horizon.png
#
# Running rolling-origin CV: 82 windows, horizon=5 ...
#   VAR lag order selected: p = 1
# Saved: output\predictions_comparison.png
# Saved: output\error_per_step.png
#
# ...
#               PREDICTION SUMMARY
# ...
# Dataset              : events_indices.csv
# N time steps         : 431
# Prediction horizon H : 5
#
# --- Forecast Horizon (from LLE) ---
#   LLE          = 0.003132
#   Initial sep  = 0.4977
#   Tolerance    = 1.0000
#   T_max        = 222.8 steps
#
# --- Cross-Validation Results ---
#   Method                    MAE       RMSE
#   ------------------------------------------
#   Analogues              0.8627     1.0752
#   LocalLinear            2.9660     9.0627
#   VAR                    0.8022     0.9854
#
#   Best method: VAR  (lowest RMSE = 0.9854)
# ...
